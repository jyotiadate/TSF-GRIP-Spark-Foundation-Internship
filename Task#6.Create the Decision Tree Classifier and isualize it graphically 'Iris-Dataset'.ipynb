# %% [markdown]
# # Task#5 . Create the Decision Tree Classifier and isualize it graphically

# %% [markdown]
# ## GRIP@ The Spark Foundation

# %% [markdown]
# ### Author: Jyoti Adate

# %% [markdown]
# ### Problem Statement-
# The purpose is it we feed any new data to this classifier ,it would be able to predict the right class accordingly.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Train Decision Tree on Classification Task

# %%
from sklearn.datasets import load_iris
iris=load_iris()

# %%
iris_data=pd.read_csv('iris.csv')
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn import tree
clf=tree.DecisionTreeClassifier()
clf=clf.fit(iris.data,iris.target)

# %% [markdown]
# ### Text Representation

# %%
txt_representation = tree.export_text(clf)
print(txt_representation)
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: 0
# |--- feature_2 >  2.45
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_2 <= 5.45
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  5.45
# |   |   |   |   |   |--- class: 2
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: 2

# %%
with open("decistion_tree.log", "w") as fout:
    fout.write(txt_representation)

# %% [markdown]
# ### Plot Tree

# %%
fig = plt.figure(figsize=(35,30))
_ = tree.plot_tree(clf, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)

# %%
fig.savefig("decistion_tree.png")

# %% [markdown]
# ### Visualize Decision Tree with graphviz

# %%
import graphviz
# DOT data
dot_data = tree.export_graphviz(clf, out_file=None, 
                                feature_names=iris.feature_names,  
                                class_names=iris.target_names,
                                filled=True)

# Draw graph
graph = graphviz.Source(dot_data, format="png") 
graph
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, capture_output, quiet, **kwargs)
#      82             assert iter(input_lines) is input_lines
# ---> 83             proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      84         else:
#
# C:\Anaconda\lib\site-packages\graphviz\backend\execute.py in _run_input_lines(cmd, input_lines, kwargs)
#     102 def _run_input_lines(cmd, input_lines, *, kwargs):
# --> 103     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     104
#
# C:\Anaconda\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# ...

# %%
graph.render("decision_tree_graphivz")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, capture_output, quiet, **kwargs)
#      84         else:
# ---> 85             proc = subprocess.run(cmd, **kwargs)
#      86     except OSError as e:
#
# C:\Anaconda\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     492
# --> 493     with Popen(*popenargs, **kwargs) as process:
#     494         try:
#
# C:\Anaconda\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
# ...

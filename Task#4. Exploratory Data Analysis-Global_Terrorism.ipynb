# %% [markdown]
# ## Task #4: Perform 'Exploratory Data Analysis' on dataset 'Global Terrorism'

# %% [markdown]
# ## GRIP@ The Spark Foundation

# %% [markdown]
# ### Author: Jyoti Adate

# %% [markdown]
# ### Problem Statement-
# . Perform 'Exploratory Data Analysis' on dataset 'Global Terrorism'.
#
# . As a security/defence analyst, try tofind out the hot zone of terrorism.
#
# . What all security issues and onsights derive by EDA ?

# %% [markdown]
# ### Import Lybraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('globalterrorismdb_0718dist.csv')
data
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# ...

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# ### I found out the total number of rows and columns in the data set

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Collect useful columns for dataset.

# %%
#Rename columns in order to get better format
data.rename(columns={'eventid':'Eventid', 'iyear':'Year', 'imonth':'Month', 'iday':'Day', 
                          'extended':'Extended', 'resolution':'Resolution',  'attacktype1_txt':'Attacktype', 
                          'country_txt':'Country', 'region_txt':'Region', 'provstate': 'Provstate', 
                          'city':'City', 'crit1':'Crit1', 'crit2':'Crit2', 
                          'crit3':'Crit3', 'multiple':'Multiple', 'success':'Success', 'suicide':'Suicide', 
                          'targtype1_txt':'Targtype', 'natlty1_txt':'Natlty1', 'natlty2_txt':'Natlty2', 
                          'natlty3_txt':'Natlty3', 'gname':'Gname', 'gname2':'Gname2', 'gname3':'Gname3', 
                          'guncertain1':'Guncertain1', 'guncertain2':'Guncertain2', 'guncertain3':'Guncertain3', 
                          'claimed':'Claimed', 'weaptype1_txt':'Weaptype', 'weapsubtype1_txt':'Weapsubtype', 
                          'nkill':'Nkill', 'nkillus':'Nkillus', 'nkillter':'Nkillter', 'nwound':'Nwound', 
                          'nwoundus':'Nwoundus', 'nwoundte':'Nwoundter', 'property':'Property', 
                          'propextent_txt':'Propextent', 'propvalue':'Propvalue', 'ishostkid':'Ishostkid', 
                          'nhostkid':'Nhostkid', 'nhostkidus':'Nhostkidus', 'ransom':'Ransom', 
                          'hostkidoutcome':'Hostkidoutcome', 'nreleased':'Nreleased'},inplace=True)

#Keep 20 columns
df = data[['Eventid', 'Year','Country', 'Region', 'Provstate', 'City', 'Crit1', 'Crit2', 'Crit3', 
                  'Success', 'Suicide', 'Attacktype', 'Targtype', 'Natlty1','Gname', 'Guncertain1', 
                  'Claimed', 'Weaptype', 'Nkill','Nwound']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Eventid      181691 non-null  int64
#  1   Year         181691 non-null  int64
#  2   Country      181691 non-null  object
#  3   Region       181691 non-null  object
#  4   Provstate    181270 non-null  object
#  5   City         181257 non-null  object
#  6   Crit1        181691 non-null  int64
#  7   Crit2        181691 non-null  int64
#  8   Crit3        181691 non-null  int64
#  9   Success      181691 non-null  int64
#  10  Suicide      181691 non-null  int64
#  11  Attacktype   181691 non-null  object
#  12  Targtype     181691 non-null  object
#  13  Natlty1      180132 non-null  object
#  14  Gname        181691 non-null  object
#  15  Guncertain1  181311 non-null  float64
#  16  Claimed      115571 non-null  float64
#  17  Weaptype     181691 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Eventid            0
# Year               0
# Country            0
# Region             0
# Provstate        421
# City             434
# Crit1              0
# Crit2              0
# Crit3              0
# Success            0
# Suicide            0
# Attacktype         0
# Targtype           0
# Natlty1         1559
# Gname              0
# Guncertain1      380
# Claimed        66120
# Weaptype           0
# Nkill          10313
# Nwound         16311
# dtype: int64

# %%
print('Country with the highest number of Terrorist Attacks:',df['Country'].value_counts().index[0])
print('Regions with the highest number of  Terrorist Attacks:',df['Region'].value_counts().index[0])
print('Maximum number of people were killed by a single terrorist attack are',df['Nkill'].max(),'people that took place in: ',df.loc[df['Nkill'].idxmax()].Country)
# Out:
# Country with the highest number of Terrorist Attacks: Iraq
# Regions with the highest number of  Terrorist Attacks: Middle East & North Africa
# Maximum number of people were killed by a single terrorist attack are 1570.0 people that took place in:  Iraq

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# #### 1. Number of Attacks in each Year

# %%
attacks=df['Year'].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={'index':'Year','Year':'Attaacks'}).set_index('Year')
attacks.head()
# Out:
#       Attaacks
# Year
# 1970       651
# 1971       471
# 1972       568
# 1973       473
# 1974       581

# %%
attacks.plot(kind='bar',color='cornflowerblue',figsize=(15,6),fontsize=13)
plt.title('Timeline of Attacks',fontsize=15)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Number of Attcks',fontsize=15)
plt.show()

# %% [markdown]
# #### 2.Total Guncertain1 in each year

# %%
year_casua=df[['Year','Guncertain1']].groupby('Year').sum()
year_casua.head()
# Out:
#       Guncertain1
# Year
# 1970         60.0
# 1971         22.0
# 1972          9.0
# 1973          8.0
# 1974         10.0

# %%
year_casua.plot(kind='bar',color='cornflowerblue',figsize=(15,6),fontsize=13)
plt.title('Year wise Guncertain1',fontsize=15)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Number of Guncertain1',fontsize=15)
plt.show()

# %% [markdown]
# #### 3 Killed in each Year

# %%
year_kill=df[['Year','Nkill']].groupby('Year').sum()
year_kill.head()
# Out:
#       Nkill
# Year
# 1970  174.0
# 1971  173.0
# 1972  566.0
# 1973  370.0
# 1974  539.0

# %%
year_kill.plot(kind='bar',color='cornflowerblue',figsize=(15,6),fontsize=13)
plt.title('People killed in each year ',fontsize=15)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Number of people killed',fontsize=15)
plt.show()

# %% [markdown]
# ### 2. Region wise Attacks

# %% [markdown]
# #### 1. Distribution of Terrorist Attcks over Region from 1970-2017

# %%
region=pd.crosstab(df.Year,df.Region)
region.head()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          28            472
# 1971            1               5                          55            247
# 1972            0               1                          53             73
# 1973            2               1                          19             64
# 1974            4               2                          42            111
#
# ...

# %%
region.plot(kind='area',stacked=False,alpha=0.5,figsize=(20,20))
plt.title('Region wise attckks',fontsize=20)
plt.xlabel('Years',fontsize=20)
plt.ylabel('Number of Attcks',fontsize=20)
plt.show()

# %% [markdown]
# #### 2.Total killed in each year

# %%
reg=df[['Region','Nkill']].groupby('Region').sum().sort_values(by='Nkill',ascending=False)
reg
# Out:
#                                 Nkill
# Region
# Middle East & North Africa   137642.0
# South Asia                   101319.0
# Sub-Saharan Africa            78386.0
# South America                 28849.0
# Central America & Caribbean   28708.0
# Southeast Asia                15637.0
# Eastern Europe                 7415.0
# Western Europe                 6694.0
# North America                  4916.0
# East Asia                      1152.0
# Central Asia                   1000.0
# Australasia & Oceania           150.0

# %%
reg.plot(kind='bar',color='cornflowerblue',figsize=(15,6),fontsize=13)
plt.title('People killed in each year ',fontsize=15)
plt.xlabel('Region',fontsize=15)
plt.ylabel('Number of people killed',fontsize=15)
plt.show()

# %% [markdown]
# #### 3. Wounded in each year

# %%
wou=df[['Region','Nwound']].groupby('Region').sum().sort_values(by='Nwound',ascending=False)
wou
# Out:
#                                Nwound
# Region
# Middle East & North Africa   214308.0
# South Asia                   141360.0
# Sub-Saharan Africa            52857.0
# Southeast Asia                26259.0
# North America                 21531.0
# Western Europe                18332.0
# South America                 16704.0
# Eastern Europe                12045.0
# East Asia                      9213.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# Australasia & Oceania           260.0

# %%
wou.plot(kind='bar',color='cornflowerblue',figsize=(15,6),fontsize=13)
plt.title('People Nwound in each year ',fontsize=15)
plt.xlabel('Resion',fontsize=15)
plt.ylabel('Number of people Nwound',fontsize=15)
plt.show()

# %% [markdown]
# ### 3. Country wise Attacks

# %% [markdown]
# #### 1. Number of Attcks in each year

# %%
country_att=df[['Country']].value_counts().head(10)
country_att.head
# Out:
# <bound method NDFrame.head of Country
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# dtype: int64>

# %%
country_att.plot(kind='bar',color='blue',figsize=(15,6),fontsize=13)
plt.title('Number of Attack in each year ',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Number of Attack',fontsize=15)
plt.show()

# %% [markdown]
# #### 2.Number of Claimed in each year

# %%
country_cla=df[['Country','Claimed']].groupby('Country').sum().sort_values(by='Claimed',ascending=False)
country_cla
# Out:
#              Claimed
# Country
# Afghanistan   2937.0
# Pakistan      1224.0
# Somalia        919.0
# Syria          700.0
# Egypt          431.0
# ...              ...
# Sri Lanka     -373.0
# Colombia      -376.0
# Russia        -425.0
# Iraq          -520.0
# Thailand      -647.0
#
# [205 rows x 1 columns]

# %%
country_cla.plot(kind='bar',color='blue',figsize=(15,6),fontsize=13)
plt.title('People Claimed in each year ',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Number of people claimed',fontsize=15)
plt.show()

# %% [markdown]
# #### 3. Number of people Killed in each year

# %%
country_kill=df[['Country','Nkill']].groupby('Country').sum().sort_values(by='Nkill',ascending=False)
country_kill
# Out:
#                        Nkill
# Country
# Iraq                 78589.0
# Afghanistan          39384.0
# Pakistan             23822.0
# Nigeria              22682.0
# India                19341.0
# ...                      ...
# St. Kitts and Nevis      0.0
# Martinique               0.0
# Brunei                   0.0
# Iceland                  0.0
# South Yemen              0.0
#
# [205 rows x 1 columns]

# %%
country_kill.plot(kind='bar',color='blue',figsize=(15,6),fontsize=13)
plt.title('People Killed in each year ',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Number of people Killed',fontsize=15)
plt.show()

# %% [markdown]
# ### 4. City Wise Attacks

# %% [markdown]
# #### 1. Number of Attacks in each year

# %%
city_att=df[['City']].value_counts().head(10)
city_att.head
# Out:
# <bound method NDFrame.head of City
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# dtype: int64>

# %%
city_att.plot(kind='bar',color='blue',figsize=(15,6),fontsize=13)
plt.title('Number of Attack in each year ',fontsize=15)
plt.xlabel('City',fontsize=15)
plt.ylabel('Number of Attack',fontsize=15)
plt.show()

# %% [markdown]
# #### 2.Number of Claimed in each year

# %%
city_cla=df[['City','Claimed']].groupby('City').sum().sort_values(by='Claimed',ascending=False)
city_cla
# Out:
#            Claimed
# City
# Mogadishu    337.0
# Kabul        233.0
# Athens       183.0
# Quetta       179.0
# Arish        144.0
# ...            ...
# Guwahati     -76.0
# Baqubah      -78.0
# Kirkuk      -119.0
# Unknown     -275.0
# Baghdad     -915.0
#
# [36674 rows x 1 columns]

# %%
city_cla.plot(kind='bar',color='blue',figsize=(15,6),fontsize=13)
plt.title('People Claimed in each year ',fontsize=15)
plt.xlabel('City',fontsize=15)
plt.ylabel('Number of people claimed',fontsize=15)
plt.show()

# %% [markdown]
# #### 3. Number of people killed in each year

# %%
city_kill=df[['City','Nkill']].groupby('City').sum().sort_values(by='Nkill',ascending=False)
city_kill

# %%
city_kill.plot(kind='bar',color='blue',figsize=(15,6),fontsize=13)
plt.title('People Killed in each year ',fontsize=15)
plt.xlabel('City',fontsize=15)
plt.ylabel('Number of people Killed',fontsize=15)
plt.show()

# %% [markdown]
# ### 5. Target Type wise Attacks

# %% [markdown]
# #### 1. Number of Attacks over each Target Type

# %%
target=df['Targtype '].value_counts().head(10)
target

# %%
target.plot(kind='bar',color='blue',figsize=(15,6),fontsize=13)
plt.title('Number of Attack in each year ',fontsize=15)
plt.xlabel('Targtype',fontsize=15)
plt.ylabel('Number of Attack',fontsize=15)
plt.show()

# %% [markdown]
# #### 2. Number of Claimed in each year

# %%
tar=df[['Targtype','Claimed']].groupby('Targtype').sum().sort_values(by='Claimed',ascending=False)
tar

# %%
tar.plot(kind='bar',color='blue',figsize=(15,6),fontsize=13)
plt.title('Number of Attack in each year ',fontsize=15)
plt.xlabel('Targtype',fontsize=15)
plt.ylabel('Number of Attack',fontsize=15)
plt.show()

# %% [markdown]
# ### 6. Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017

# %% [markdown]
# #### 1.Total Claimed due to Terrorist Attacks

# %%
clam=df.loc[:,'Claimed'].sum()
print('Total number of Claimed due to Terrorist Attacks from 1970 to 2017 across the world :',clam)
